# %% [markdown]
# #1. Importazione delle librerie necessarie

# %% [markdown]
# In questa sezione vengono importate tutte le librerie necessarie: per la gestione e manipolazione dei dati, per la costruzione e valutazione dei modelli, per visualizzazioni e grafici, per il preprocessing dei dati e codifica, per la gestione dello sbilanciamento nella variabile target e per la costruzione di micro-pipeline per rendere più compatti e veloci alcune parti di codice.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline #per una gestione più efficiente e veloce di transformer e modelli
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
    )
from imblearn.over_sampling import SMOTE #per gestire lo sbilanciamento con oversampling
from imblearn.under_sampling import RandomUnderSampler #per gestire lo sbilanciamento con undersampling
from sklearn.model_selection import learning_curve # per creare learning curve
from collections import Counter #per gestione di SMOTE e RUS

#impostazioni grafiche
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (6, 6)
print("_____Import librerie completato_____")
# Out:
# _____Import librerie completato_____

# %% [markdown]
# #2. Caricamento del dataset

# %% [markdown]
# In questa sezione viene importato il dataset in formato csv e viene omessa la prima colonna con l'identificativo dell'osservazione. Infine è stampata la dimensione del dataset (numero di esempi e features).

# %%
url='https://proai-datasets.s3.eu-west-3.amazonaws.com/insurance_cross_sell.csv'
df = pd.read_csv(url,index_col=0) #prima colonna con indice
print("_____Import dataset completato_____\n")
print(f"Numero di righe: {df.shape[0]}, Numero di colonne: {df.shape[1]}")
# Out:
# _____Import dataset completato_____
#
# Numero di righe: 381109, Numero di colonne: 11

# %% [markdown]
# #3. Esplorazione del dataset

# %% [markdown]
# In questa sezione viene mostrata un'analisi esplorativa del dataset: dalle generalità ad un approfondimento sulla target e sulla relazione con le features.

# %% [markdown]
# ###3.1 Generalità

# %%
#prime 10 righe dataset
print("_____Anteprima dataset (prime 10 righe)_____\n")
df.head(10)
# Out:
# _____Anteprima dataset (prime 10 righe)_____
#     Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# id
# 1     Male   44                1         28.0                   0   > 2 Years
# 2     Male   76                1          3.0                   0    1-2 Year
# 3     Male   47                1         28.0                   0   > 2 Years
# 4     Male   21                1         11.0                   1    < 1 Year
# 5   Female   29                1         41.0                   1    < 1 Year
# 6   Female   24                1         33.0                   0    < 1 Year
# 7     Male   23                1         11.0                   0    < 1 Year
# 8   Female   56                1         28.0                   0    1-2 Year
# 9   Female   24                1          3.0                   1    < 1 Year
# 10  Female   32                1          6.0                   1    < 1 Year
#
# ...

# %% [markdown]
# Dettagli features e target:
# - id: identificativo univoco del cliente.
# - Gender: sesso del cliente.
# - Age: età del cliente.
# - Driving_License: 1 se il cliente possiede la patente di guida, 0 altrimenti.
# - Region_Code: codice univoco della regione di residenza del cliente.
# - Previously_Insured: 1 se il cliente ha già un veicolo assicurato, 0 altrimenti.
# - Vehicle_Age: età del veicolo del cliente.
# - Vehicle_Damage: 1 se il cliente ha avuto incidenti o danni al veicolo in passato, 0 altrimenti.
# - Annual_Premium: importo annuale del premio assicurativo pagato dal cliente.
# - PolicySalesChannel: canale utilizzato per la vendita della polizza (es. email, telefono, di persona).
# - Vintage: giorni da cui il cliente è assicurato con AssurePredict.
# - Response: 1 se il cliente ha accettato la proposta di cross-sell, 0 altrimenti.

# %%
#info generali
print("_____Informazioni fenerali sul dataset_____\n")
df.info()
# Out:
# _____Informazioni fenerali sul dataset_____
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 381109 entries, 1 to 381109
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                381109 non-null  object
#  1   Age                   381109 non-null  int64
#  2   Driving_License       381109 non-null  int64
#  3   Region_Code           381109 non-null  float64
#  4   Previously_Insured    381109 non-null  int64
#  5   Vehicle_Age           381109 non-null  object
#  6   Vehicle_Damage        381109 non-null  object
#  7   Annual_Premium        381109 non-null  float64
#  8   Policy_Sales_Channel  381109 non-null  float64
#  9   Vintage               381109 non-null  int64
#  10  Response              381109 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# Già da questi primi output si evidenzia la necessaria codifica delle variabili categoriche (alcune sono già codificate, altre sono già da codificare). Si fa presente che nonostante la maggior parte delle variabili siano riconosciute come numeriche, in realtà sono solo tre.<br>
# Di seguito le statistiche descrittive per le sole variabili numeriche.

# %%
#statistiche descrittive per variabili numeriche
print("_____Statistiche descrittive (colonne numeriche)_____\n")
df[['Age', 'Annual_Premium', 'Vintage']].describe()
# Out:
# _____Statistiche descrittive (colonne numeriche)_____
#                  Age  Annual_Premium        Vintage
# count  381109.000000   381109.000000  381109.000000
# mean       38.822584    30564.389581     154.347397
# std        15.511611    17213.155057      83.671304
# min        20.000000     2630.000000      10.000000
# 25%        25.000000    24405.000000      82.000000
# 50%        36.000000    31669.000000     154.000000
# 75%        49.000000    39400.000000     227.000000
# max        85.000000   540165.000000     299.000000

# %% [markdown]
# Da un primo sguardo non sembrano esserci anomalie nelle statistiche descrittive e i range di massimo-minimo sono plausibili per le tre features numeriche.

# %%
#valori mancanti
print("_____Valori mancanti per colonna_____\n")
df.isnull().sum()
#stesso output per df.isna().sum()
# Out:
# _____Valori mancanti per colonna_____
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# Il dataset risulta interamente bilanciato (assenza di valori mancanti)

# %% [markdown]
# ###3.2 Analisi variabile target (Response)

# %%
print("_____Distribuzione della variabile target (valori assoluti)_____\n")
response_abs_counts = df['Response'].value_counts()
print(response_abs_counts)

print()

print("_____Distribuzione della variabile target (valori relativi in percentuale)_____\n")
response_counts = df['Response'].value_counts(normalize=True)*100
print(round(response_counts,2))

print()

plt.figure(figsize=(4, 3))
sns.countplot(x='Response', data=df, palette='viridis', hue='Response', legend=False)
plt.title('Distribuzione della variabile target (Response)')
plt.xlabel('Risposta (0 = No, 1 = Yes)')
plt.ylabel('Conteggio clienti\n(esempi)')
plt.xticks([0, 1], [f'No ({response_counts[0]:.2f}%)', f'Yes ({response_counts[1]:.2f}%)'])
plt.tight_layout()
plt.show()
# Out:
# _____Distribuzione della variabile target (valori assoluti)_____
#
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64
#
# _____Distribuzione della variabile target (valori relativi in percentuale)_____
#
# Response
# 0    87.74
# 1    12.26
# Name: proportion, dtype: float64

# %% [markdown]
# La variabile target è fortemente sbilanciata. Infatti solo il 12.26% dei clienti ha risposto positivamente all'offerta (ovvero solo il 12.26% degli esempi presenta una target=1).<br>
# Questo sbilanciamento sarà gestito in fase di modellazione e verranno mostrate tre soluzioni per il modello più appropriato.

# %% [markdown]
# ###3.3 Analisi features categoriche vs Response

# %%
#Gender vs Response
col_name = 'Gender'
plt.figure(figsize=(6, 3))
order = sorted(df[col_name].unique())
sns.countplot(x=col_name, data=df, hue='Response', order=order, palette='viridis', dodge=True,stat="probability")
plt.title(f'Distribuzione Response per {col_name}')
plt.xlabel(col_name)
plt.ylabel('Frequenza relativa')
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

# Driving_License vs Response
col_name = 'Driving_License'
plt.figure(figsize=(6,3))
order = sorted(df[col_name].unique())
sns.countplot(x=col_name, data=df, hue='Response', order=order, palette='viridis', dodge=True,stat="probability")
plt.title(f'Distribuzione Response per {col_name}')
plt.xlabel(f'{col_name}')
plt.ylabel('Frequenza relativa')
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Region_Code vs Response (Top 10)
col_name = 'Region_Code'
plt.figure(figsize=(6,3))
if df[col_name].nunique() > 10:
    top_categories = df[col_name].value_counts().nlargest(10).index
    df_filtered = df[df[col_name].isin(top_categories)]
else:
    top_categories = df[col_name].unique()  #se meno di 10 usa tutte
    df_filtered = df
sns.countplot(x=col_name, data=df_filtered, hue='Response',
              order=top_categories, palette='viridis', dodge=True,
              stat="probability")
plt.title(f'Distribuzione Response per {col_name} (Top 10)')
plt.xlabel(f'{col_name}')
plt.ylabel('Frequenza Relativa')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Previously_Insured vs Response
col_name = 'Previously_Insured'
plt.figure(figsize=(6,3))
order = sorted(df[col_name].unique())
sns.countplot(x=col_name, data=df, hue='Response', order=order, palette='viridis', dodge=True,stat="probability")
plt.title(f'Distribuzione Response per {col_name}')
plt.xlabel(f'{col_name}')
plt.ylabel('Frequenza Relativa')
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Vehicle_Age vs Response
col_name = 'Vehicle_Age'
plt.figure(figsize=(6,3))
category_order = ['< 1 Year', '1-2 Year', '> 2 Years'] #definizione esplicita dell'ordine delle categorie
sns.countplot(x=col_name, data=df, hue='Response', order=category_order, palette='viridis', dodge=True,stat="probability")
plt.title(f'Distribuzione Response per {col_name}')
plt.xlabel(col_name)
plt.ylabel('Frequenza Relativa')
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Vehicle_Damage vs Response
col_name = 'Vehicle_Damage'
df[col_name] = df[col_name].replace({'Yes': 1, 'No': 0})
plt.figure(figsize=(6,3))
order = sorted(df[col_name].unique())
sns.countplot(x=col_name, data=df, hue='Response', order=order, palette='viridis', dodge=True,stat="probability")
plt.title(f'Distribuzione Risposta per {col_name}')
plt.xlabel(f'{col_name}')
plt.ylabel('Conteggio Clienti')
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.legend(title='Response', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-91-066d671f1d7b>:73: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col_name] = df[col_name].replace({'Yes': 1, 'No': 0})

# %% [markdown]
# Lo sbilanciamento nelle distribuzioni è evidente e notevole. Emergono interessanti pattern:
# - La propensione ad accettare l'offerta di cross-selling è superiore negli uomini piuttosto che nelle donne nel campione.
# - Nella regione con codice 28 c'è la più alta percentuale di risposta positiva all'offerta.
# - Gli individui precedentemente assicurati non hanno acettato in alcun caso l'offerta. Quindi la propensione ad accettare è più alta in individui che precedentemente NON avevano veicoli assicurati.
# - Se il veicolo ha da 1 a 2 anni allora la propensione ad accettare l'offerta è superiore rispetto a quando il veicolo è stato comprato di recente (< 1 anno) oppure se ha una età superiore a 2. Si evidenzia che il rapporto tra chi accetta e chi rifiuta è più alto nei casi di veicoli con età > 2 anni (infatti in questo caso il rapporto è quasi 0.5, invece nelle restanti tre categorie è sicuramente più basso).
# - Gli individui che non hanno avuto incidenti rifiutano sempre l'offerta. Invece tra chi ha avuto incidenti, circa 1/3 accetta.
# <br>
# <br>
# Già questa analisi basta ad indirizzare le campagne di marketing verso clienti target dove c'è un alto tasso di rifiuto ma comunque la propensione ad accettare è bassa ma positiva.

# %% [markdown]
# ###3.4 Analisi features numeriche vs Response

# %%
# Age vs Response (istogramma)
col_name = 'Age'
plt.figure(figsize=(6,3))
sns.histplot(data=df, x=col_name, hue='Response', kde=True, palette='viridis', multiple='stack',stat="probability")
plt.title(f'Distribuzione di {col_name} per Response')
plt.xlabel(col_name)
plt.ylabel('Frequenza')
plt.tight_layout()
plt.show()

#Age vs Response (boxplot)
col_name = 'Age'
plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Response', y=col_name, palette='viridis',hue='Response', legend=False)
plt.title(f'Boxplot di {col_name} per Response')
plt.xlabel('Response (0 = No, 1 = Yes)')
plt.ylabel(col_name)
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Annual_Premium vs Response (istogramma)
col_name = 'Annual_Premium'
premium_limit = 70000 # Filtro poichè valori sopra 70000 sono diversi ma con frequenza bassissima e in questo contesto sono poco informativi
df_filtered_premium = df[df[col_name] < premium_limit]
plt.figure(figsize=(8,5))
sns.histplot(data=df_filtered_premium, x=col_name, hue='Response', kde=True, palette='viridis', multiple='stack',stat="probability")
plt.title(f'Distribuzione di {col_name} (< {premium_limit}) per Response')
plt.xlabel(f'{col_name} (filtrato)')
plt.ylabel('Frequenza')
plt.tight_layout()
plt.show()

#Annual_Premium vs Response (boxplot)
col_name = 'Annual_Premium'
premium_limit = 99999999999 # NON applicazione filtro
df_filtered_premium = df[df[col_name] < premium_limit]
plt.figure(figsize=(7,4))
sns.boxplot(data=df_filtered_premium, x='Response', y=col_name, palette='viridis',hue='Response', legend=False)
plt.title(f'Boxplot di {col_name} per Response')
plt.xlabel('Response (0 = No, 1 = Yes)')
plt.ylabel(f'{col_name}')
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

#Vintage vs Response (istogramma): omesso perchè per nulla informativo

#Vintage vs Response (boxplot)
col_name = 'Vintage'
plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Response', y=col_name, palette='viridis',hue='Response', legend=False)
plt.title(f'Boxplot di {col_name} per Response')
plt.xlabel('Response (0 = No, 1 = Yes)')
plt.ylabel(f'{col_name} (Giorni)')
plt.xticks([0, 1], ['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Anche in questa analisi emergono interessanti pattern:
# - Il più alto tasso di accettazione della proposta si riscontra nella fascia d'età tra 40 e 50 anni. D'altra parte gli individui tra 20 e 30 anni sono molto più propensi a rifiutare. L'ipotesi che si potrebbe avanzare è che gli individui più giovani hanno probabilmente fatto pochi incidenti (o nessuno) e dai pattern precedenti si è visto che chi non ha fatto incidenti è incline a rifiutare.
# - La distribuzione per età di chi accetta presenta degli outliers quando è superiore a 75 anni.
# - Quando il premio assicurativo annuale è basso, la propensione ad accettare è molto alto. Si tenga conto che nelle distribuzioni di Annual_Premium (sia nel caso di Response=1 che di Response=0) ci sono molti ouliers quando la feature assume valori superiori a circa 50000.

# %% [markdown]
# ###3.5 Analisi features numeriche

# %%
numerical_cols = ['Age', 'Annual_Premium', 'Vintage'] #colonne variabili numeriche

#matrice di correlazione
plt.figure(figsize=(6, 6))
correlation_matrix = df[numerical_cols + ['Response']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matrice di Correlazione tra Variabili Numeriche e Response')
plt.tight_layout()
plt.show()

# %% [markdown]
# La matrice di correlazione mostra che non ci sono correlazioni lineari molto forti tra le variabili numeriche e la target, ma soprattutto che tra di esse non ci sono alti gradi di correlazione.

# %% [markdown]
# # 4. Preprocessing dei dati

# %% [markdown]
# In questa sezione viene mostrato il pre-processamento dei dati.<br>
# Vengono estratte prima le features numeriche e categoriche (divise in features ad alta e bassa cardinalità ma trattate in modo identico per semplicità). Poi sono create ed applicate due micro-pipeline (aggregate infine in una sola) per il preprocessing delle features in base alla natura.

# %%
df_processed =df.copy() #creo una copia del dataset

# separazione delle features (X) dalla variabile target (y)
X = df_processed.drop('Response', axis=1)
y = df_processed['Response']

#colonne numeriche e categoriche per il preprocessing
numerical_features = ['Age', 'Annual_Premium', 'Vintage']
# considero 'Region_Code' e 'Policy_Sales_Channel' come categoriche ad alta cardinalità e le altre come binarie o a bassa cardinalità
categorical_features_low_cardinality = ['Gender', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage']

# OneHotEncoding potrebbe creare troppe colonne. Per semplicità iniziale usiamo OHE, ma tecniche come target encoding potrebbero essere considerate più appropriate

#conversione Region_Code e Policy_Sales_Channel in stringhe per OHE
X['Region_Code'] = X['Region_Code'].astype(str)
X['Policy_Sales_Channel'] = X['Policy_Sales_Channel'].astype(str)
categorical_features_high_cardinality = ['Region_Code', 'Policy_Sales_Channel']

#creazione transformer per pipeline
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler()) #features numeriche
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first')) #codifica ohe, drop='first' per evitare multicollinearità, handle_unknown='ignore' fa sì che categorie sconosciute vengano semplicemente codificate come zeri, permettendo al modello di fare comunque una predizione. È utile poichè indica che il modello potrebbe incontrare dati leggermente diversi "nel mondo reale"

])

#columnTransformer per combinare i due creati sopra
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features_low_cardinality + categorical_features_high_cardinality)
    ],
    remainder='passthrough'
)

# %% [markdown]
# # 5. Divisione del dataset in training-set e test-set

# %% [markdown]
# In questa sezione si esegue lo slplitting (Hold-Out) del dataset in modo che il 70% dei dati vengano usati nei training e il 30% nei test. Di seguito vengono poi stampate le effettive dimensioni dei vari set.

# %%
#splitting dei dati prima di applicare resampling così da evitare data leakage
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,    #30% dei dati per il test
    random_state=1996,   #riproducibilità
    stratify=y         #per mantenere la proporzione delle classi nello split
)

print(f"Dimensioni Training Set: X_train={X_train.shape}, y_train={y_train.shape}")
print()
print(f"Dimensioni Test Set: X_test={X_test.shape}, y_test={y_test.shape}")
print()
print(f"Distribuzione 'Response' nel Training Set (in percentuale):\n{y_train.value_counts(normalize=True)}")
print()
print(f"Distribuzione 'Response' nel Test Set (in percentuale):\n{y_test.value_counts(normalize=True)}")
# Out:
# Dimensioni Training Set: X_train=(266776, 10), y_train=(266776,)
#
# Dimensioni Test Set: X_test=(114333, 10), y_test=(114333,)
#
# Distribuzione 'Response' nel Training Set (in percentuale):
# Response
# 0    0.877437
# 1    0.122563
# Name: proportion, dtype: float64
#
# Distribuzione 'Response' nel Test Set (in percentuale):
# Response
# 0    0.877437
# 1    0.122563
# Name: proportion, dtype: float64

# %% [markdown]
# # 6. Costruzione modelli con differente gestione dello sbilanciamento delle classi

# %% [markdown]
# Si precisa che:
# 1. Tra i vari modelli implementabili per questo progetto la regressione logistica è l'unico modello appropriato data la natura della variabile target.
# 2. Da un confronto con implementazioni omesse (Naive Bayes, Random Forest, SVC, LightGBM e XGBoost) la regressione logistica ottiene performance superiori.
# 3. Il tuning dei parametri (omesso poichè non richiesto in questo progetto) sui tre modelli presentati di seguito arrivano a richiedere dai 20 ai 60 minuti circa e nonostante l'ottimizzazione, le performance e la minimizzazione dei falsi negativi sono pressocchè identici alle configurazioni di default presentate.
# 4. Per l'applicazione del transform e del fit_transform per X test e X train viene costruita una pipeline per una gestione più veloce, ordinata ed efficente del processo (nel modello 3 invece vengono gestite queste fasi manualmente).
# <br>
# <br>
# Questa sezione si compone di 2 fasi:
# - Fase 1: sono mostrati 3 modelli (regressioni logistiche) in cui viene gestito in modo differente lo sbilanciamento nella target tramite diverse tecniche (uso del parametro class_weight='balanced', SMOTE e RUS).<br>
# Ad ogni modello segue la sua valutazione e la learning curve. Viene dunque scelto il miglior modello.
# - Fase 2: considerato che l'obiettivo è minimizzare i falsi negativi, quindi massimizzare la recall, viene proposta una variante del miglior modello in cui viene impostata manualmente la soglia di probabilità sottostante il modello logistico. Ovviamente la soglia che massimizza la recall è prossima allo zero (qualsiasi cross validation restituirebbe valori tali), quindi la proposta è un compromesso che genera un numero ragionevole di falsi negativi

# %% [markdown]
# **Differenza tra i modelli proposti nella fase 1 per gestire lo sbilanciamento tra le classi nella target:**<br>
# - LR (Balanced): Modifica i pesi nella funzione di costo senza alterare i dati e tende ad aumentare la Recall rispetto a un modello non bilanciato.
# - LR (SMOTE): Crea campioni "sintetici" della classe minoritaria e può aumentare ulteriormente la Recall talvolta a scapito della Precision (più falsi positivi). In questo caso emerge il rischio di overfitting se i campioni sintetici non sono ben rappresentativi.
# - LR (UnderSampled): Rimuove campioni della classe maggioritaria (in questo caso specifico response=0) e spesso conduce ad una Recall molto alta (il modello infatti si concentrerà sulla distinzione tra i pochi campioni rimasti). In questo caso si può riscontrare una precision molto bassa a causa della perdita di informazioni sulla classe maggioritaria.

# %%
# inizializzazione di un dizionario per salvare i risultati di ogni modello (potrebbe tornare utile in caso di molti modelli)
model_predictions = {}

# %% [markdown]
# ###6.1 Modello 1 e learning curve

# %%
#Modello 1: Logistic Regression (con class_weight='balanced')
pipeline_lr_balanced = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(solver='liblinear', class_weight='balanced', random_state=1996))
])
pipeline_lr_balanced.fit(X_train, y_train)
y_pred_lr = pipeline_lr_balanced.predict(X_test)
y_prob_lr = pipeline_lr_balanced.predict_proba(X_test)[:, 1]
model_predictions['Logistic Regression (Balanced)'] = {'pred': y_pred_lr, 'prob': y_prob_lr}
print("Valutazione:")
print(classification_report(y_test, y_pred_lr))
print(f"ROC AUC: {roc_auc_score(y_test, y_prob_lr):.4f}\n")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Valutazione:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79    100320
#            1       0.28      0.94      0.43     14013
#
#     accuracy                           0.69    114333
#    macro avg       0.63      0.80      0.61    114333
# weighted avg       0.90      0.69      0.74    114333
#
# ROC AUC: 0.8482
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# **Premessa:** <br>
# Con riferimento al messaggio di warning, durante l'applicazione del preprocessor al test set (X_test), sono stati trovati valori nella colonna con indice 6 che non erano mai stati visti durante l'addestramento (fit) sul training set (X_train). Ciò era una eventualità soprattutto nei casi, ad esempio, delle features Region_Code o Policy_Sales_Channel.
# Questa situazione è gestita tramite il parametro handle_unknown='ignore' nel OneHotEncoder. Questo fa sì che queste categorie "mai viste" vengano trasformate in un vettore di zeri, permettendo al modello di procedere nell'elaborazione.<br>
# <br>
# **Classe 1:**<br>
# - precision: 0.28: valore molto basso. Quando il modello predice "1", solo il 28% delle volte la previsione è corretta. Il restante 72% sono falsi positivi.<br>
# - recall: 0.94: questo valore è estremamente alto. Il modello riesce a identificare correttamente il 94% di tutti i clienti che hanno accettato la proposta di cross-selling (basso numero di falsi negativi).<br>
# f1-score: 0.43: essendo la media armonica di precision e recall, questo valore è basso, trascinato verso il basso dalla scarsa precision. Indica un cattivo bilanciamento tra le due metriche per questa classe.
#
# **Classe 0:**<br>
# - precision: 0.99: molto alta. Se il modello predice "0", è quasi certamente corretto.<br>
# - recall: 0.66: valore medio-basso. Il modello identifica correttamente solo il 66% dei clienti che non accettano. Il restante 34% dei non interessati viene erroneamente classificato come interessato (questi sono i falsi positivi che causano la bassa precisione per la classe 1).<br>
# -f1-score: 0.79: è un valore medio-alto ed indica un buon bilanciamento tra le due metriche per questa classe.
#
# **Accuracy:** 0.69: Questa metrica è ingannevole a causa del forte sbilanciamento delle classi, quindi non è affidabile in questo contesto.
#
# **ROC AUC:** 0.8482: questo è un punteggio (score) buono. Indica che il modello, indipendentemente dalla soglia di classificazione, ha una buona capacità di distinguere un cliente che accetta da uno che non accetta. È significativamente migliore di un modello casuale (AUC = 0.5).

# %%
#learning curve modello 1

#definisco le dimensioni del training set da usare. proporzioni: da 10% a 100% dei dati di training, in 5 step
#i punteggi per la learning curve sono calcolati tramite cross-validation
train_sizes_proportions = np.linspace(0.1, 1.0, 5)

# uso l'intera pipeline come estimator eroc_auc come metrica
train_sizes_abs, train_scores, validation_scores = learning_curve(
    estimator=pipeline_lr_balanced, #modello/pipeline da valutare
    X=X_train,    #feature di training
    y=y_train,     #target di training
    train_sizes=train_sizes_proportions, #frazioni del training da usare
    cv=5,     #strategia di cross-validation (5-fold)
    scoring='roc_auc',  #metrica per la valutazione
    n_jobs=-1,   #per usare tutti i core CPU
    random_state=1996    #per riproducibilità CV
)

#media e la deviazione standard dei punteggi per ogni dimensione
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
validation_scores_mean = np.mean(validation_scores, axis=1)
validation_scores_std = np.std(validation_scores, axis=1)

plt.figure(figsize=(10, 6))

#area per la deviazione standard
plt.fill_between(train_sizes_abs, train_scores_mean - train_scores_std,
                  train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes_abs, validation_scores_mean - validation_scores_std,
                  validation_scores_mean + validation_scores_std, alpha=0.1, color="g")

#curve delle medie
plt.plot(train_sizes_abs, train_scores_mean, 'o-', color="r",
          label="Training score (ROC AUC)")
plt.plot(train_sizes_abs, validation_scores_mean, 'o-', color="g",
          label="Cross-validation score (ROC AUC)")

plt.title("Learning Curve - Logistic Regression (Balanced)")
plt.xlabel("Numero di Esempi di Training")
plt.ylabel("ROC AUC Score")
plt.legend(loc="best")
plt.grid(True)
plt.ylim(None, 1.01)
plt.tight_layout()
plt.show()

#punteggio finale
print(f"\nPunteggio medio finale di Cross-Validation (con {train_sizes_abs[-1]} esempi): {validation_scores_mean[-1]:.4f}")
# Out:
# Punteggio medio finale di Cross-Validation (con 213420 esempi): 0.8493

# %% [markdown]
# La lerning curve mostra che da un piccolo gap iniziale tra training e test, poi si converge più o meno verso uno stesso valore. Quindi il modello apprende e generalizza bene. Le performance non sono eccellenti ma comunque buone.<br>
# Sicuramente il modello non è in overfitting, ma aggiungere altri dati non migliorerà le performance. Migliori performance sono auspicabili con l'applicazione di altri modelli oppure aggiungendo features più informative.

# %% [markdown]
# ###6.2 Modello 2 e learning curve

# %%
#Modello 2: Logistic Regression (con SMOTE)
#creazione di una ImbPipeline per includere SMOTE. la pipeline di imblearn applica SMOTE solo durante il fit
pipeline_lr_smote = ImbPipeline(steps=[
    ('preprocessor', preprocessor), # Step 1: Preprocessing
    ('sampler', SMOTE(random_state=1996)), # Step 2: SMOTE applicato solo su fit
    ('classifier', LogisticRegression(solver='liblinear',
                                      random_state=1996)) # Step 3: Classificatore SENZA class_weight
])

#addestramento della pipeline (SMOTE viene applicato internamente ai dati pre-processati) ed effetto di SMOTE durante il fit
print(f"Distribuzione classi (Training) prima di SMOTE (nel fit): {Counter(y_train)}")
pipeline_lr_smote.fit(X_train, y_train)

# Predizione sul test set originale (la pipeline applica solo il preprocessor)
print("Predizione Logistic Regression...")
#predict su pipeline SMOTE e dati ORIGINALI
y_pred_lr_smote = pipeline_lr_smote.predict(X_test)
y_prob_lr_smote = pipeline_lr_smote.predict_proba(X_test)[:, 1]

#salvataggio i risultati e valutazione
model_predictions['Logistic Regression (SMOTE)'] = {'pred': y_pred_lr_smote, 'prob': y_prob_lr_smote}

print("Valutazione:")
print(classification_report(y_test, y_pred_lr_smote))
print(f"ROC AUC: {roc_auc_score(y_test, y_prob_lr_smote):.4f}\n")
# Out:
# Distribuzione classi (Training) prima di SMOTE (nel fit): Counter({0: 234079, 1: 32697})
# Predizione Logistic Regression...
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Valutazione:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79    100320
#            1       0.28      0.93      0.43     14013
#
#     accuracy                           0.69    114333
#    macro avg       0.63      0.79      0.61    114333
# weighted avg       0.90      0.69      0.74    114333
#
# ROC AUC: 0.8475

# %% [markdown]
# **Premessa:** <br>
# Vale quanto detto precedentemente sul messaggio di warning. Inoltre di seguito sono evidenziate solo le differenze col modello precedente dato che hanno performance pressocchè identiche.<br>
# <br>
# **Classe 1:**<br>
# - recall: 0.93: è un valore estremamente alto e suggeriche che il modello riesce a identificare correttamente il 93% di tutti i clienti che hanno accettato la proposta di cross-selling (basso numero di falsi negativi).<br>
#
# **Classe 0:**<br>
# - Tutte le metriche sono identiche al modello precedente.
#
# **Accuracy:** identica al modello precedente.
#
# **ROC AUC:** 0.8475: è un buon punteggio, leggermente inferiore a quello del modello precedente.

# %%
#learning curve modello 2
train_sizes_proportions = np.linspace(0.1, 1.0, 5)

#training pipeline
train_sizes_abs, train_scores, validation_scores = learning_curve(
    estimator=pipeline_lr_balanced,
    X=X_train,
    y=y_train,
    train_sizes=train_sizes_proportions,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=1996
)


# calcolo  media e deviazione standard dei punteggi per ogni dimensione
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
validation_scores_mean = np.mean(validation_scores, axis=1)
validation_scores_std = np.std(validation_scores, axis=1)

plt.figure(figsize=(10, 6))

#area deviazione standard
plt.fill_between(train_sizes_abs, train_scores_mean - train_scores_std,
                  train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes_abs, validation_scores_mean - validation_scores_std,
                  validation_scores_mean + validation_scores_std, alpha=0.1, color="g")

#curve delle medie
plt.plot(train_sizes_abs, train_scores_mean, 'o-', color="r",
          label="Training score (ROC AUC)")
plt.plot(train_sizes_abs, validation_scores_mean, 'o-', color="g",
          label="Cross-validation score (ROC AUC)")

plt.title("Learning Curve - Logistic Regression (Balanced)")
plt.xlabel("Numero di Esempi di Training")
plt.ylabel("ROC AUC Score")
plt.legend(loc="best")
plt.grid(True)
plt.ylim(None, 1.01)
plt.tight_layout()
plt.show()

#punteggio
print(f"\nPunteggio medio finale di Cross-Validation (con {train_sizes_abs[-1]} esempi): {validation_scores_mean[-1]:.4f}")
# Out:
# Punteggio medio finale di Cross-Validation (con 213420 esempi): 0.8493

# %% [markdown]
# L'andamento della learning curve ha le stesse caratteristiche del modello precedente.

# %% [markdown]
# ###6.3 Modello 3 e learning curve

# %%
#Modello 3: Logistic Regression (con RUS)

#applicazione preprocessing (prima di RUS). non uso pipeline per questo modello specifico
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

#applicazione RandomUnderSampler ai dati di training processati
rus = RandomUnderSampler(random_state=1996, sampling_strategy='auto') #RUS
print(f"Distribuzione classi (Training) prima di RUS: {Counter(y_train)}")
# applicazione fit_resample solo ai dati di training processati
X_train_rus, y_train_rus = rus.fit_resample(X_train_processed, y_train) #dati undersampled
print(f"Distribuzione classi (Training) dopo RUS: {Counter(y_train_rus)}")
print(f"Dimensione Training Set dopo RUS: {X_train_rus.shape}")

#Logistic Regression (senza class_weight) e classificatore senza class_weight='balanced'
lr_under_classifier = LogisticRegression(solver='liblinear',
                                          random_state=1996)
#addestramento sul dataset ridotto (su undersampled)
lr_under_classifier.fit(X_train_rus, y_train_rus)

#Predizione sul test set originale processato usando il classificatore addestrato e i dati X_test_processed
y_pred_lr_under = lr_under_classifier.predict(X_test_processed)
y_prob_lr_under = lr_under_classifier.predict_proba(X_test_processed)[:, 1]

#salvataggio risultati nel dizionario con la nuova chiave
model_predictions['Logistic Regression (UnderSampled)'] = {'pred': y_pred_lr_under, 'prob': y_prob_lr_under}

print("Valutazione:")
#valutazione usando le nuove predizioni
print(classification_report(y_test, y_pred_lr_under))
print(f"ROC AUC: {roc_auc_score(y_test, y_prob_lr_under):.4f}\n")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [6] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Distribuzione classi (Training) prima di RUS: Counter({0: 234079, 1: 32697})
# Distribuzione classi (Training) dopo RUS: Counter({0: 32697, 1: 32697})
# Dimensione Training Set dopo RUS: (65394, 210)
# Valutazione:
#               precision    recall  f1-score   support
#
#            0       0.99      0.66      0.79    100320
#            1       0.28      0.94      0.43     14013
#
#     accuracy                           0.69    114333
#    macro avg       0.63      0.80      0.61    114333
# weighted avg       0.90      0.69      0.74    114333
#
# ROC AUC: 0.8477

# %% [markdown]
# **Premessa:** <br>
# Vale quanto detto precedentemente sul messaggio di warning. Inoltre di seguito sono evidenziate solo le differenze col modello precedente dato che hanno performance pressocchè identiche.<br>
# <br>
# **Classe 1:**<br>
# - recall: 0.94: è un valore alto, come nei due modelli precedenti e suggeriche che il modello riesce a identificare correttamente il 94% di tutti i clienti che hanno accettato la proposta di cross-selling (con un conseguente basso numero di falsi negativi).<br>
#
# **Classe 0:**<br>
# - Tutte le metriche sono identiche al modello precedente.
#
# **Accuracy:** identica al modello precedente.
#
# **ROC AUC:** 0.8477: è un buon punteggio, leggermente inferiore a caso del primo modello ma superiore a quello del modello precedente.

# %%
#learning curve modello 3

#pipeline
pipeline_lr_undersampled_lc = ImbPipeline(steps=[
    ('preprocessor', preprocessor), #preprocessing
    ('sampler', RandomUnderSampler(random_state=1996)), #RUS (applicato solo su fit)
    ('classifier', LogisticRegression(solver='liblinear',#classificatore
                                      random_state=1996))
])

#parametri per learning_curve
train_sizes_proportions = np.linspace(0.1, 1.0, 5) # 5 passi dal 10% al 100% (come i precedenti)

#learning curve
#sono usati i dati di training originali (X_train e y_train) e la pipeline applica preprocessing e RUS internamente
train_sizes_abs, train_scores, validation_scores = learning_curve(
    estimator=pipeline_lr_undersampled_lc,
    X=X_train,
    y=y_train,
    train_sizes=train_sizes_proportions,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    random_state=1996
)

#calcolo media e deviazione standard dei punteggi
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
validation_scores_mean = np.mean(validation_scores, axis=1)
validation_scores_std = np.std(validation_scores, axis=1)

#plot learning curve
plt.figure(figsize=(10, 6))
plt.fill_between(train_sizes_abs, train_scores_mean - train_scores_std,
                  train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes_abs, validation_scores_mean - validation_scores_std,
                  validation_scores_mean + validation_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes_abs, train_scores_mean, 'o-', color="r", label="Training score (ROC AUC)")
plt.plot(train_sizes_abs, validation_scores_mean, 'o-', color="g", label="Cross-validation score (ROC AUC)")
plt.title("Learning Curve - Logistic Regression (UnderSampled)")
plt.xlabel("Numero di Esempi di Training (Originali)")
plt.ylabel("ROC AUC Score")
plt.legend(loc="best")
plt.grid(True)
plt.ylim(None, 1.01)
plt.tight_layout()
plt.show()

#punteggio finale
print(f"\nPunteggio medio finale di Cross-Validation (con {train_sizes_abs[-1]} esempi originali): {validation_scores_mean[-1]:.4f}")
# Out:
# Punteggio medio finale di Cross-Validation (con 213420 esempi originali): 0.8490

# %% [markdown]
# L'andamento della learning curve ha le stesse caratteristiche dei modelli precedenti.

# %% [markdown]
# ### 6.4 Fase 2 e implementazione del Modello 4

# %% [markdown]
# Dei tre modelli precedentemente presentati, poichè hanno tutti un ROC AUC simile, quello con più bassa recall è quello in cui viene applicato il RUS (modello 3). Di questo modello, nella presente sezione, viene proposta la variante (Modello 4) con impostazione manuale della soglia di probabilità sottostante al modello.

# %%
# Modello 4: variante modello 3 (Logistic Regression UnderSampled con soglia di probabilità impostata manualmente)

manual_threshold_variant_rus = 0.25  #genera meno di 200 falsi negativi. Per meno di 100 il valore da impostare è 0.1
print(f"Soglia manuale per la variante (basata sul modello 3 - RUS) impostata a: {manual_threshold_variant_rus}")

#applicazione della soglia manuale alle probabilità y_prob_lr_under
y_pred_lr_under_variant = (y_prob_lr_under >= manual_threshold_variant_rus).astype(int)

#valutazione performance soglia esplicitata
print(f"\nValutazione Modello 4 con soglia = {manual_threshold_variant_rus}):")
print(classification_report(y_test, y_pred_lr_under_variant, zero_division=0))

#salvataggio nuove predizioni nel dizionario
model_key_variant_rus = f'LR (UnderSampled - Thr={manual_threshold_variant_rus:.2f})' #<---------------------------------------------------- LEGGI NOTA SOTTO!
if 'model_predictions' not in locals(): model_predictions = {}
model_predictions[model_key_variant_rus] = {
    'pred': y_pred_lr_under_variant,
    'prob': y_prob_lr_under # Le probabilità originali del modello base non cambiano
}

# Il ROC AUC è basato sulle probabilità y_prob_lr_under quindi non cambia al variare della soglia.
print(f"ROC AUC (basato su y_prob_lr_under, indipendente dalla soglia): {roc_auc_score(y_test, y_prob_lr_under):.4f}\n")


#NOTA con riferimento alla riga evidenziata sopra (    model_key_variant_rus = f'LR (UnderSampled - Thr={manual_threshold_variant_rus:.2f})'   ):
#La chiave per il dizionario sarà, in questo caso, LR (UnderSampled - Thr=0.25) e non cambierà automaticamente se viene mossa la soglia
#quindi in caso di modifiche alla soglia, bisogna modificare manualmente nella sezione delle conclusioni la chiave in result per avere il confronto
#tra i modelli e le matrici di confusione.
# Out:
# Soglia manuale per la variante (basata sul modello 3 - RUS) impostata a: 0.25
#
# Valutazione Modello 4 con soglia = 0.25):
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73    100320
#            1       0.24      0.99      0.39     14013
#
#     accuracy                           0.62    114333
#    macro avg       0.62      0.78      0.56    114333
# weighted avg       0.90      0.62      0.69    114333
#
# ROC AUC (basato su y_prob_lr_under, indipendente dalla soglia): 0.8477

# %% [markdown]
# La learning curve del modello 4 è omessa poichè è uguale a quella del modello 3.<br>
# La  Variante Modello 3 (ovvero Modello 4) non ridefinisce il processo di addestramento ma semplicemente prende le probabilità generate dal lr_under_classifier (processo Modello 3) e applica una soglia diversa da 0.5.
# La learning curve per il modello 3 è la stessa che analizza il modello che sta alla base della Variante del modello 3 (ovvero Modello 4). <br>
# La learning curve si concentra sul processo di apprendimento del modello ed è indipendente dalla scelta della soglia di decisione finale.

# %% [markdown]
# L'obiettivo posto è quindi stato raggiunto. Ovvero un modello con una recall del 99% circa con performance non eccellenti a comunque buone.

# %% [markdown]
# # 7. Confronto tra i modelli e conclusioni

# %% [markdown]
# In questa sezione vengono comparati i modelli costruiti e viene scelto il modello finale. Si ricorda che l'obiettivo è minimizzare i falsi negativi quindi la metrica a cui si darà più peso è la recall della classe response=1. Di seguito viene mostrata anche la matrice di confusione per i tre modelli.

# %%
#lista modelli da confrontare
models_to_compare = [
    'Logistic Regression (Balanced)',
    'Logistic Regression (SMOTE)',
    'Logistic Regression (UnderSampled)',
    'LR (UnderSampled - Thr=0.25)'
]

results_list = []
#ciclo
for name in models_to_compare:
    result = model_predictions.get(name)

    pred = result['pred']
    score = result['prob'] #probabilità per roc-auc

    #metriche
    results_list.append({
        'Modello': name,
        'Accuracy': accuracy_score(y_test, pred),
        'Precision (Class 1)': precision_score(y_test, pred, pos_label=1, zero_division=0),
        'Recall (Class 1)': recall_score(y_test, pred, pos_label=1, zero_division=0),
        'F1-Score (Class 1)': f1_score(y_test, pred, pos_label=1, zero_division=0),
        'ROC AUC': roc_auc_score(y_test, score)
    })

#dataframe risultati
if results_list:
    results_df = pd.DataFrame(results_list)
    print("_____Performance modelli_____")
    print(results_df.round(4).sort_values(by='ROC AUC', ascending=False))

    #ROC curves modelli
    plt.figure(figsize=(10, 7))

    for name in models_to_compare:
         result = model_predictions.get(name)

         score = result['prob']
         fpr, tpr, _ = roc_curve(y_test, score)
         auc = roc_auc_score(y_test, score)
         plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.4f})")

    plt.plot([0, 1], [0, 1], 'k--', label='Random Chance') #modello random
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR) / Recall')
    plt.title('Confronto Curve ROC - Logistic Regression Variants')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# _____Performance modelli_____
#                               Modello  Accuracy  Precision (Class 1)  \
# 0      Logistic Regression (Balanced)    0.6917               0.2764
# 2  Logistic Regression (UnderSampled)    0.6901               0.2757
# 3        LR (UnderSampled - Thr=0.25)    0.6221               0.2433
# 1         Logistic Regression (SMOTE)    0.6917               0.2757
#
#    Recall (Class 1)  F1-Score (Class 1)  ROC AUC
# 0            0.9366              0.4268   0.8482
# 2            0.9389              0.4262   0.8477
# 3            0.9871              0.3903   0.8477
# 1            0.9318              0.4256   0.8475

# %%
#lista modelli
models_to_plot_cm = [
    'Logistic Regression (Balanced)',
    'Logistic Regression (SMOTE)',
    'Logistic Regression (UnderSampled)',
    'LR (UnderSampled - Thr=0.25)'
]

#iterazione su ciascun modello
for model_name in models_to_plot_cm:
    print("______________________________________________________________________________")
    print(f"\n \n_____{model_name}_____")

    #estrazione predizioni dal dizionario
    result = model_predictions.get(model_name)

    y_pred = result['pred']

    #matrice di confusione
    #[[TN, FP], [FN, TP]]
    cm = confusion_matrix(y_test, y_pred)

    print("Matrice di Confusione (array):")
    print(cm)
    tn, fp, fn, tp = cm.ravel()
    print(f"TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=[0, 1])

    fig, ax = plt.subplots(figsize=(6, 5))
    disp.plot(ax=ax, cmap='Blues', values_format='d')
    ax.set_title(f"Confusion Matrix\n{model_name}")

    ax.grid(False)
    plt.tight_layout()
    plt.show()
# Out:
# ______________________________________________________________________________
#
#
# _____Logistic Regression (Balanced)_____
# Matrice di Confusione (array):
# [[65957 34363]
#  [  889 13124]]
# TN: 65957, FP: 34363, FN: 889, TP: 13124
# ______________________________________________________________________________
#
#
# _____Logistic Regression (SMOTE)_____
# Matrice di Confusione (array):
# [[66026 34294]
#  [  956 13057]]
# TN: 66026, FP: 34294, FN: 956, TP: 13057
# ______________________________________________________________________________
#
#
# _____Logistic Regression (UnderSampled)_____
# Matrice di Confusione (array):
# [[65747 34573]
#  [  856 13157]]
# TN: 65747, FP: 34573, FN: 856, TP: 13157
# ______________________________________________________________________________
#
#
# _____LR (UnderSampled - Thr=0.25)_____
# Matrice di Confusione (array):
# [[57294 43026]
#  [  181 13832]]
# TN: 57294, FP: 43026, FN: 181, TP: 13832

# %% [markdown]
# Con una recall di 0.9871 e un ROC AUC di 0.8477. Il Modello 4 è il miglior modello per il problema che si sta affrontando. Dalla matrice di confusione si evidenzia che i falsi negativi ottenuti sono solo 181.<br>
# Un ipotetico modello 5 (estremo) con soglia di probabilità prossima a 0 genererebbe falsi negativi prossimi a 0.
